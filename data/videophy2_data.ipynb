# %%
from IPython.display import Video

# %%
from datasets import load_dataset

# Login using e.g. `huggingface-cli login` to access this dataset
ds = load_dataset("videophysics/videophy2_train")
# Out:
# README.md: 0.00B [00:00, ?B/s]
# videophy2_training.csv: 0.00B [00:00, ?B/s]
# Generating train split:   0%|          | 0/3343 [00:00<?, ? examples/s]

# %%
ds["train"][0]['video_url']
# Out:
# 'https://videophysics2trainvideos.s3.us-east-2.amazonaws.com/cogvideoX5b_hard_train_upsampled/A_Segway_bumps_over_a_series_of_small_speed_bumps,_the_rider_maintaining_balance_with_slight_adjustments.mp4'

# %%
TEST_VIDEO_IDX = 1
video_url = ds["train"][TEST_VIDEO_IDX]['video_url']
video_url
# Out:
# 'https://videophysics2trainvideos.s3.us-east-2.amazonaws.com/cogvideoX5b_hard_train_upsampled/A_Segway_moves_across_a_sandy_beach,_leaving_visible_tire_tracks_and_kicking_up_small_sand_clouds.mp4'

# %%
Video(video_url)
# Out:
# <video src="https://videophysics2trainvideos.s3.us-east-2.amazonaws.com/cogvideoX5b_hard_train_upsampled/A_Segway_moves_across_a_sandy_beach,_leaving_visible_tire_tracks_and_kicking_up_small_sand_clouds.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>
